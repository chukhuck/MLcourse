# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array(Image.open('source.jpg'))
plt.imshow(img)

# %%
from sobel import Segmenter

segmenter = Segmenter()
filtered_image, mask = segmenter.process_image("source.jpg")
segmenter.save_results("result.jpg")
# Out:
# Результат сохранен в: result.jpg

# %%
img = np.array(Image.open('result.jpg'))
plt.imshow(img)
