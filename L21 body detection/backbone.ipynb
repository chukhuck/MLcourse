# %%
import os
from posture import PostureTracker

tracker = PostureTracker()

video_path = "data/backbone/1.mp4" 
output_path = "data/backbone_output/1_analysis.mp4"  

if output_path:
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

tracker.process_video(video_path, output_path)
# Out:
# Запуск анализа осанки...
# Нажмите 'q' для выхода, 'p' для паузы
#
# ...
# ИТОГОВАЯ СТАТИСТИКА ОСАНКИ
# ...
# Всего проанализировано кадров: 10179
# Кадры с хорошей осанкой: 3 (0.0%)
# Кадры с плохой осанкой: 10176 (100.0%)
# 💪 Нужно уделить больше внимания осанке!
