# %%
import os
from smiledetector import SmileDetector



detector = SmileDetector()

# Пути к каталогам
input_dir = "data/input"
output_dir = "data/smile"

# Проверяем существование входного каталога
if not os.path.exists(input_dir):
    print(f"Ошибка: Входной каталог {input_dir} не существует!")

# Обрабатываем изображения
detector.process_directory(input_dir, output_dir)
# Out:
# Начинаем обработку каталога: data/input
# Обрабатывается: a_1.jpg
#   Mouth ratio: 101.88
#   ✗ Улыбка не обнаружена: a_1.jpg
# Обрабатывается: a_2.jpg
#   Mouth ratio: 1.13
#   ✗ Улыбка не обнаружена: a_2.jpg
# Обрабатывается: a_3.jpg
#   Mouth ratio: 43.62
#   ✗ Улыбка не обнаружена: a_3.jpg
# Обрабатывается: sad_1.jpg
#   Mouth ratio: 78.92
#   ✗ Улыбка не обнаружена: sad_1.jpg
# Обрабатывается: sad_2.jpg
#   Mouth ratio: 28.01
#   ✗ Улыбка не обнаружена: sad_2.jpg
# Обрабатывается: sad_3.jpg
#   Mouth ratio: 29.30
#   ✗ Улыбка не обнаружена: sad_3.jpg
# Обрабатывается: sad_4.jpg
#   Mouth ratio: 47.24
#   ✗ Улыбка не обнаружена: sad_4.jpg
# Обрабатывается: sad_5.jpg
#   Mouth ratio: 175.61
#   ✗ Улыбка не обнаружена: sad_5.jpg
# Обрабатывается: s_1.jpg
#   Mouth ratio: 4.14
#   ✓ Улыбка обнаружена, копируем: s_1.jpg
# Обрабатывается: s_2.jpg
#   Mouth ratio: 2.51
#   ✓ Улыбка обнаружена, копируем: s_2.jpg
# Обрабатывается: s_3.jpg
#   Mouth ratio: 3.11
#   ✓ Улыбка обнаружена, копируем: s_3.jpg
# Обрабатывается: s_4.jpg
#   Mouth ratio: 4.14
#   ✓ Улыбка обнаружена, копируем: s_4.jpg
# Обрабатывается: s_5.png
#   Mouth ratio: 2.48
#   ✓ Улыбка обнаружена, копируем: s_5.png
#
# Обработка завершена!
# Всего обработано изображений: 13
# Найдено улыбающихся: 5
# Скопировано в: data/smile
