# %%
import os
from clapcounter import ClapCounter


counter = ClapCounter()
    

video_path = "data/jump/2.mp4"  
output_path = "data/jump_output/2_counted.mp4" 


if output_path:
    os.makedirs(os.path.dirname(output_path), exist_ok=True)


clap_count = counter.process_video(video_path, output_path)

print(f"\nИтоговый результат: {clap_count} хлопков над головой")
# Out:
# Начинаем обработку видео...
# Нажмите 'q' для выхода, 'p' для паузы
#
# Обработка завершена!
# Всего хлопков над головой: 6
# Обработано кадров: 570
#
# Итоговый результат: 6 хлопков над головой
