# %% [markdown]
# 1. P = 5/1000 = 0.005
#
# 2.  P = 6/20 = 0.3
#
# 3. P = 4/16 = 0.25
#
# 4. P = C(8,6) = 0.75
#
# 5. P = 3/4 = 0.75
#
# 6. P = 2/20 = 0.1
#
# 7. P = 6/12 = 0.5
#
# 8. P = 3/12 = 0.25
#
# 9. P = 2/4 = 0.5
#
# 10. P = 1/4 = 0.25
#
# 11. P = 1 - 0.19 = 0.81
#
# 12. P = 1 - 0.965 = 0.035
#
# 13. P = 0.1 + 0.6 = 0.7
