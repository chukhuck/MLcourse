# %%
import pandas as pd
import numpy as np

data = np.random.randn(10, 4)
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.752648 -0.965066  1.311548  1.488044
# 1 -0.915625  0.592107  2.139347 -0.013573
# 2 -0.208665 -0.887509 -1.876325 -0.149792
# 3  2.146678 -1.675621 -0.609967 -1.086262
# 4  2.053122  0.751367 -1.738903 -0.489916
# 5 -0.021440 -0.502081 -0.596281  1.241427
# 6 -1.633161 -1.705950 -0.801381  0.680072
# 7  0.794652 -1.144704 -0.235751  0.149437
# 8 -0.856541 -1.103394 -0.332667  0.766986
# 9 -0.645583 -0.579722  0.634854 -1.652710
