# %%
import pandas as pd
import numpy as np

data = np.random.randn(10, 4)
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0 -1.088257  0.928426  0.962511  1.283363
# 1 -2.209695 -0.529070  0.734216  0.137048
# 2  0.247842  1.110492  0.490093  0.913132
# 3 -0.908047  0.533771 -0.058498  1.055137
# 4 -1.106447  0.491765  0.271891 -1.611624
# 5 -0.326200  0.150125  0.388196 -2.875633
# 6 -0.048084 -0.630340 -0.921027 -0.651604
# 7 -0.540060  0.478518 -0.354747 -1.414780
# 8 -0.552184  0.689036  0.011123  1.010842
# 9 -0.087444  0.875629 -1.174510 -0.269976
