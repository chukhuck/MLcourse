# %%
import pandas as pd
import numpy as np

data = np.random.randn(10, 4)
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.511054  0.000657 -1.627184  0.663840
# 1  1.651403  0.703757 -0.371454 -1.066605
# 2 -0.913606  1.544488  0.579890 -0.870812
# 3  0.007733  0.202001  1.084788 -1.087908
# 4 -0.082518 -0.804585  1.074585  0.969018
# 5 -1.206760 -0.045262  1.496874  0.626215
# 6 -0.610298 -0.615276 -0.305996  0.744095
# 7 -0.677655 -0.061709  0.093750 -0.311380
# 8 -0.543827 -1.079547  0.859359 -0.677345
# 9 -1.037413 -1.352268  1.299363 -0.337628
